# %% [markdown]
# # Summary of the badger meter exploration
# Screens with descriptions summing up the recent exploration

# %% [markdown]
# ## Few examples of basic statistics

# %%
from IPython.display import Image

# %%
'''
As expected most locations show the greatest water usage on the weekends. Using such patterns that are characteristic for each individual meter location we may find unexpected behavious and based on them develop further research on eg. anomalies detection
'''
Image(filename='flow_dayweek.png')

# %%
'''
Using box plot one may notice the distribution of flow values in chosen meter id. As shown below there are some obvious unexpected values eg. over 125 gallons that may be classified as outliers but there may also some hidden ones for which we need another detection techniques that are shown later.
'''
Image(filename='boxplot.png')

# %%
'''
There are examples in the date set where as shown below certain flow shift takes place. We may address such cases and find probable cause for the shift eg. leaking event. The research of the flow shift in time enabled us to be sure that the data has listed problems and that we understand how to approach them.
'''
Image(filename='flow_shift.png')

# %% [markdown]
# # Signal strength summary
# On the bar plots below, the signal strength equal to 1 belongs to the highest signal available and the value equal to 3 to the weakest signal.

# %%
'''
We searched for signal strength and device parameters correlations. We found that we can only say something about rerely used devices' sizes as the rest is equally distributed among all signal strengths that appear. We could conclude that certain sizes may have impact on signal strength but it is for now only a hypotesis.
'''
Image(filename='signal_model.png')

# %%
''''
Similarly as with meter size, the meter model distribution may be used to analyse the models that are rarely used but which meter ids show marginal or medium signal strength.
''''
Image(filename='signal_type.png')

# %%
'''
The location of the worst and medium signal may be noticed (the locations of the best signal are not shown as there are 34799 of them and the map would not be readable. There wasn't observed strong correlation between location and signal strengh. However as we lack the information about the change of signal in time and only have one date available for all meters we cannot go further into the topic. The details about provider are also not specified, we don't know which meter id has which provider. If we could have more detailed data on the topic then the research could be developed further.
'''
Image(filename='signal_map.png')

# %% [markdown]
# # Leaking and anomalies observations

# %%
'''
Based on the data about last leaking occurences in all meter ids' locations one may notice patterns in terms of leaking occurence during the year. The season of the year has significant impact on the frequency of the leaking events.
'''
Image(filename='month_leak.png')

# %%
'''
One may use the leaking detailed data to find the artificial line for outliers detection. As shown in the plots below, there is visible pattern in terms of leaking events and the respond from the flow values. The plot is based on one meter id's history.
'''
Image(filename='leak_scatter.png')

# %%
'''
Showing here the plot of one meter id flow in time, one may notice that using information about leaking it is possible to detect places with higest probability of the value being an anomaly. It is crucial in further research on different methods of anomaly detection and ways of dealing with such events.
'''
Image(filename='leak_border.png')

# %%
'''
Having the knowledge about past events in given meter id, one may used it for the prediction of the outliers in the future. It may be noticed on the plot below that the flow responds similarly when experiencing the leaking or any other unexpected external factors that change its volume of the water.
'''
Image(filename='leak_repeat.png')

# %% [markdown]
# # Freezing analysis

# %%
'''
Having the data about freezing event in given meter ids, we could predict whether a given location experienced freezing or not. This may be used for further understading of the freezing of the devices. If we could have more detailed data, and see how the freezing occurs in time series, we could make more accurate prediction and know not only if the meter id freezed but also when it may freeze in the near future.
'''
Image(filename='bm-logistic1.png')

# %%
# Image showing the current accuracy which is approximately 90%.
Image(filename='bm-logistic2.png')

# %% [markdown]
# # Singular spectrum analysis

# %%
'''
One may use the singular spectrum transform for finding the points of change in flow in oder to identify probable anomalies occurences. The blue plot shows the points in time where it is probable that the flow behaved unexpectedly and should be research more as it may be a result of the eg. device shift or leaking event.
'''

# %%
# Plot showing the flow in time
Image(filename='flow_plot.png')

# %%
# Plot showing the identified points of change and their strength (how significant they are)
Image(filename='change_point.png')

# %% [markdown]
# ## Another approach to point of change in time series

# %%
'''
We may use many different approaches for finding the point of change in flow time series. The one below is another method used for such exploration. If the research goes further we may develop more complex techniques for this problem of the points of change detection.
'''
Image(filename='leaking-edivisive.png')

# %%
# Plot showing the above results in greatest period of time, blue vertical lines show the points of change.
Image(filename='leaking-edivisive2.png')
